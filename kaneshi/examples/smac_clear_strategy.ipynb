# %%
import sys
sys.path.insert(1, 'D:/kaneshi')
import kaneshi

from kaneshi.core.market_data import MarketData
from kaneshi.core.strategies import SMACClear

# %%
m_config = {'symbol': 'BTCUSDT',
            'interval': 1,
            's_date': (2021, 1, 1),
            'e_date': (2021, 1, 5),
            'columns': 'Close',
            'price_type': 'Close',
           }

market = MarketData.from_config(**m_config)

# %%
s_config = {
    'sma': 14,
    'lma': 50,
    'market_data': market,
}

s = SMACClear(**s_config).apply()

# %%
s.generate_report(type_='df')
# Out:
#    n_trades  equal_return  cumulative_return  win_rate  mean_trade_time  \
# 0        70     -1.672527          -2.094407  0.314286        40.642857
#
#    max_return  max_drawdown
# 0    0.050045     -0.012539

# %%
s.plot(plot_type='plt')  # problems with z order

# %%
s.plot_return(plot_type='plt', dep_type='cumulative')
