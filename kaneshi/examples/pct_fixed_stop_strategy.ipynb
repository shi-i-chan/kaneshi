# %%
import sys
sys.path.insert(1, 'D:/kaneshi')
import kaneshi

from kaneshi.core.market_data import MarketData
from kaneshi.core.strategies import PCTFixedStop

# %%
m_config = {'symbol': 'BTCUSDT',
            'interval': 1,
            's_date': (2021, 1, 1),
            'e_date': (2021, 1, 5),
            'columns': 'Close',
            'price_type': 'Close',
           }

market = MarketData.from_config(**m_config)

# %%
s_config = {
    'pct_period': 14,
    'pct_edge': 0.01,
    'stop_loss_percent': -0.01,
    'take_profit_percent': 0.01,
    'market_data': market,
}

s = PCTFixedStop(**s_config).apply()

# %%
s.generate_report(type_='df')
# Out:
#    n_trades  equal_return  cumulative_return  win_rate  mean_trade_time  \
# 0        66     -5.902285          -6.043284  0.530303        62.151515
#
#    max_return  max_drawdown
# 0        0.01         -0.01

# %%
s.plot(plot_type='plt')  # bad visual

# %%
s.plot_return(plot_type='plt', dep_type='cumulative')
